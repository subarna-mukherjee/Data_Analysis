# %%
import pandas as pd

# %%
df=pd.read_csv('8. Netflix Dataset.csv')
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.size
# Out:
# 85679

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
#to find duplicated entries
df[df.duplicated()]
df.drop_duplicates(inplace=True)
#df.shape

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 11       s12  TV Show                                     1983
# 12       s13  TV Show                                     1994
# 16       s17  TV Show                                   Feb-09
# 19       s20    Movie                                      '89
# ...      ...      ...                                      ...
# 7779   s7778  TV Show                              Zombie Dumb
# 7781   s7780  TV Show                                Zona Rosa
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                   Director                                               Cast  \
# 0                      NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#showing the null values using heat map
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
sns.heatmap(df.isnull())
plt.show()

# %%
df['Duration']=df.Duration.str.split(' ',expand=True).iloc[:,0]
df['Duration']=df.Duration.astype('int')

# %%
#for 'House of cards' what is the show id and whho is the director?
df.info()
df[df.Title=='House of Cards'][['Director','Show_Id']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7787 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   object
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   int32
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
# dtypes: int32(1), object(10)
# memory usage: 699.6+ KB
#                                                Director Show_Id
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...   s2833

# %%
df[df.Title.str.contains('House of Cards')][['Director','Show_Id']]#alternate method to repeat the above query
# Out:
#                                                Director Show_Id
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...   s2833

# %%
#In which year were  highest number of movies and TV shows were released
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7787 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   object
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   int32
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
# dtypes: int32(1), object(10)
# memory usage: 699.6+ KB

# %%
df.Release_Date.value_counts()
# Out:
# January 1, 2020       118
# November 1, 2019       94
# December 31, 2019      76
# March 1, 2018          76
# October 1, 2018        72
#                      ...
#  March 16, 2016         1
# September 11, 2019      1
# December 17, 2019       1
# September 28, 2017      1
# March 4, 2018           1
# Name: Release_Date, Length: 1565, dtype: int64

# %%
df['Release_Year']=df.Release_Date.str.split(',',expand=True)[1]

df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating  Duration  \
# 0    August 14, 2020  TV-MA         4
# 1  December 23, 2016  TV-MA        93
# 2  December 20, 2018      R        78
# 3  November 16, 2017  PG-13        80
# 4    January 1, 2020  PG-13       123
#
# ...

# %%
plt.figure(figsize=(12,10))
sns.countplot(x='Release_Year',data=df)
plt.show()
#Highest number of movies/TV shows released in 2019

# %%
#count number of movies and tv shows in the dataset,visualize
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7787 entries, 0 to 7788
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   object
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   int32
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
#  11  Release_Year  7777 non-null   object
# dtypes: int32(1), object(11)
# memory usage: 1.1+ MB

# %%
df.Category.value_counts()
# Out:
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(x='Category',data=df)
plt.show()

# %%
df_Movie=list(df.groupby('Category'))[0][1]
df_Movie
# Out:
#      Show_Id Category                                    Title  \
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# ...      ...      ...                                      ...
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# ...

# %%
df_TV_Show=list(df.groupby('Category'))[1][1]
df_TV_Show
# Out:
#      Show_Id Category                  Title              Director  \
# 0         s1  TV Show                     3%                   NaN
# 5         s6  TV Show                     46           Serdar Akar
# 11       s12  TV Show                   1983                   NaN
# 12       s13  TV Show                   1994  Diego Enrique Osorno
# 16       s17  TV Show                 Feb-09                   NaN
# ...      ...      ...                    ...                   ...
# 7769   s7768  TV Show     Zindagi Gulzar Hai                   NaN
# 7777   s7776  TV Show             Zoids Wild                   NaN
# 7779   s7778  TV Show            Zombie Dumb                   NaN
# 7781   s7780  TV Show              Zona Rosa                   NaN
# 7787   s7786  TV Show  Zumbo's Just Desserts                   NaN
#
#                                                    Cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#Show all the movies released in 2020
df_Movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5377 entries, 1 to 7788
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       5377 non-null   object
#  1   Category      5377 non-null   object
#  2   Title         5377 non-null   object
#  3   Director      5214 non-null   object
#  4   Cast          4951 non-null   object
#  5   Country       5147 non-null   object
#  6   Release_Date  5377 non-null   object
#  7   Rating        5372 non-null   object
#  8   Duration      5377 non-null   int32
#  9   Type          5377 non-null   object
#  10  Description   5377 non-null   object
#  11  Release_Year  5377 non-null   object
# dtypes: int32(1), object(11)
# memory usage: 525.1+ KB

# %%
df_Movie.Release_Year.value_counts()

#to find count of movies released in 2020
# Out:
#  2019    1497
#  2020    1312
#  2018    1255
#  2017     864
#  2016     258
#  2021      88
#  2015      58
#  2014      19
#  2011      13
#  2013       6
#  2012       3
#  2009       2
#  2008       1
#  2010       1
# Name: Release_Year, dtype: int64

# %%
#to find title of all tv shows made in India
df_TV_Show.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2410 entries, 0 to 7787
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       2410 non-null   object
#  1   Category      2410 non-null   object
#  2   Title         2410 non-null   object
#  3   Director      185 non-null    object
#  4   Cast          2118 non-null   object
#  5   Country       2133 non-null   object
#  6   Release_Date  2400 non-null   object
#  7   Rating        2408 non-null   object
#  8   Duration      2410 non-null   int32
#  9   Type          2410 non-null   object
#  10  Description   2410 non-null   object
#  11  Release_Year  2400 non-null   object
# dtypes: int32(1), object(11)
# memory usage: 235.4+ KB

# %%
df_TV_Show[df_TV_Show.Country=='India'].Title.to_frame().reset_index(drop=True)
# Out:
#                                  Title
# 0         21 Sarfarosh: Saragarhi 1897
# 1                            7 (Seven)
# 2                         Agent Raghav
# 3                         Akbar Birbal
# 4                  Anjaan: Rural Myths
# ..                                 ...
# 66                The Creative Indians
# 67  The Golden Years with Javed Akhtar
# 68              The House That Made Me
# 69                          Typewriter
# 70                     Yeh Meri Family
#
# [71 rows x 1 columns]

# %%
#top 10 directors who made maximum number of moies or tv shows
df_Movie.Director.value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              15
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Martin Scorsese           12
# Youssef Chahine           12
# Steven Spielberg          10
# David Dhawan               9
# Kunle Afolayan             8
# Name: Director, dtype: int64

# %%
df_TV_Show.Director.value_counts().head(10)
# Out:
# Alastair Fothergill                                                     3
# Rob Seidenglanz                                                         2
# Shin Won-ho                                                             2
# Iginio Straffi                                                          2
# Stan Lathan                                                             2
# Ken Burns                                                               2
# Go Koga                                                                 1
# Oscar Micheaux, Spencer Williams, Richard E. Norman, Richard Maurice    1
# DJ Chen                                                                 1
# Robert Kenner, Taki Oldham                                              1
# Name: Director, dtype: int64

# %%
df_Movie.Country
# Out:
# 1                                                  Mexico
# 2                                               Singapore
# 3                                           United States
# 4                                           United States
# 6                                                   Egypt
#                               ...
# 7783                                        United States
# 7784    Sweden, Czech Republic, United Kingdom, Denmar...
# 7785                                                India
# 7786                                                  NaN
# 7788                United Kingdom, Canada, United States
# Name: Country, Length: 5377, dtype: object

# %%
#Show all the movies which are comedies and were made in UK
df_Movie[(df_Movie.Type.str.contains('Comedies')) & (df_Movie.Country=='United Kingdom')]
# Out:
#      Show_Id Category                                              Title  \
# 287     s288    Movie                                         About Time
# 445     s446    Movie                                  Amar Akbar & Tony
# 1091   s1092    Movie                                  Breaking the Bank
# 1368   s1369    Movie                                 Christmas Survival
# 1650   s1651    Movie                Dead in a Week (Or Your Money Back)
# 2157   s2158    Movie                                         Figaro Pho
# 2189   s2190    Movie                                Fisherman's Friends
# 2225   s2226    Movie                                  For Love or Money
# 2251   s2252    Movie                        Four Weddings and a Funeral
# 2270   s2271    Movie                                          Free Fire
# 2809   s2810    Movie                       Horrid Henry's Gross Day Out
# 2822   s2823    Movie                                       Hot Property
# ...

# %%
#Number of movies
len(df_Movie[(df_Movie.Type.str.contains('Comedies')) & (df_Movie.Country=='United Kingdom')])
# Out:
# 31

# %%
#Display all movies/tv shows where Tom Cruise was starred
df.dropna(inplace=True)
df[df.Cast.str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating  Duration                        Type  \
# 3860  January 1, 2020      R       189  Dramas, Independent Movies
# 5071     July 1, 2019      R       134      Classic Movies, Dramas
#
#                                             Description Release_Year
# 3860  Through chance, human action, past history and...         2020
# 5071  A fast-talking yuppie is forced to slow down w...         2019

# %%
#To find the different ratings defined by netflix
df.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
#how many movies got tv-14 rating in Canada
df_Movie[(df_Movie.Country=='Canada')&(df_Movie.Rating=='TV-14')]
print('NUmber of movies which got TV_14 in Canada is ',len(df_Movie[(df_Movie.Country=='Canada')&(df_Movie.Rating=='TV-14')]))
# Out:
# NUmber of movies which got TV_14 in Canada is  11

# %%
df.isnull().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# Release_Year    0
# dtype: int64

# %%
df_Movie['Release_Year']=df_Movie.Release_Year.astype('int')

# %%
#LIST Of movie released after 2018,which were R rated
df_Movie[(df_Movie.Release_Year>2018)&(df_Movie.Rating=='R')]
# Out:
#      Show_Id Category               Title                       Director  \
# 7         s8    Movie                 187                 Kevin Reynolds
# 14       s15    Movie                3022                     John Suits
# 65       s66    Movie             13 Sins                   Daniel Stamm
# 68       s69    Movie           14 Blades                     Daniel Lee
# 83       s84    Movie  20th Century Women                     Mike Mills
# ...      ...      ...                 ...                            ...
# 7659   s7658    Movie           Woodshock  Kate Mulleavy, Laura Mulleavy
# 7712   s7711    Movie       Yes, God, Yes                    Karen Maine
# 7738   s7737    Movie         Young Adult                  Jason Reitman
# 7776   s7775    Movie              Zodiac                  David Fincher
# 7780   s7779    Movie          Zombieland                Ruben Fleischer
#
#                                                    Cast  \
# ...

# %%
df.Duration.value_counts()
# Out:
# 93     121
# 94     119
# 90     114
# 95     111
# 97     107
#       ...
# 17       1
# 228      1
# 224      1
# 208      1
# 201      1
# Name: Duration, Length: 193, dtype: int64

# %%
df.Duration.max()
# Out:
# 253

# %%
#Which is the longest TV/Show or Movie
df[df.Duration==df.Duration.max()].Title
# Out:
# 6852    The School of Mischief
# Name: Title, dtype: object

# %%
df.Duration.min()
# Out:
# 1

# %%
df[df.Duration==df.Duration.min()].Title.to_frame()
# Out:
#                              Title
# 5                               46
# 132                      7 (Seven)
# 218                A Queen Is Born
# 260                       A.I.C.O.
# 276                   Abby Hatcher
# ...                            ...
# 7090          Til Death Do Us Part
# 7120                   To the Lake
# 7315  Unabomber - In His Own Words
# 7387                       Valeria
# 7494                Watership Down
#
# [97 rows x 1 columns]

# %%
df_TV_Show.Country.value_counts().head(1)
#MAximum number of TV shows produced by United States
# Out:
# United States    705
# Name: Country, dtype: int64

# %%
df_Movie.Country.value_counts().head(1)
print(df_Movie.Country.value_counts().head(1),' produces the maximum number of movies.')
# Out:
# United States    1850
# Name: Country, dtype: int64  produces the maximum number of movies.

# %%
df[((df.Category=='Movie')&(df.Type.str.contains('Dramas')))]
# Out:
#      Show_Id Category     Title           Director  \
# 1         s2    Movie     07:19  Jorge Michel Grau
# 4         s5    Movie        21     Robert Luketic
# 7         s8    Movie       187     Kevin Reynolds
# 10       s11    Movie      1922       Zak Hilditch
# 15       s16    Movie    Oct-01     Kunle Afolayan
# ...      ...      ...       ...                ...
# 7776   s7775    Movie    Zodiac      David Fincher
# 7778   s7777    Movie  Zokkomon   Satyajit Bhatkal
# 7782   s7781    Movie       Zoo       Shlok Sharma
# 7784   s7783    Movie      Zozo        Josef Fares
# 7785   s7784    Movie    Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 10    Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...
# 15    Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...
# ...

# %%
df[((df.Category=='TV Show')&(df.Type.str.contains("Kids'")))]
# Out:
#      Show_Id Category                                       Title  \
# 276     s277  TV Show                                Abby Hatcher
# 2380   s2381  TV Show                            Geronimo Stilton
# 2439   s2440  TV Show                     Glitter Force Doki Doki
# 3238   s3239  TV Show                      Julie and the Phantoms
# 3582   s3583  TV Show            Lego Friends: Girls on a Mission
# 3851   s3852  TV Show            Maggie & Bianca: Fashion Friends
# 4121   s4122  TV Show     Miraculous: Tales of Ladybug & Cat Noir
# 4582   s4583  TV Show                    Oggy and the Cockroaches
# 5187   s5187  TV Show                            Revolting Rhymes
# 6037   s6037  TV Show       Th Eena Meena Deeka Chase Comedy Show
# 6204   s6204  TV Show  The Cat in the Hat Knows a Lot About That!
# 7058   s7057  TV Show                          Thomas and Friends
# 7668   s7667  TV Show                               World of Winx
#
#                         Director  \
# ...

# %%
#Find all instances where 
#Category is Movie and Type is drama OR
#Category is TV Show and Type is Drama
df.Type.value_counts()
df[((df.Category=='Movie')&(df.Type.str.contains('Dramas',regex=True)))|((df.Category=='TV Show')&(df.Type.str.contains("Kids'",regex=True)))]
# Out:
#      Show_Id Category     Title           Director  \
# 1         s2    Movie     07:19  Jorge Michel Grau
# 4         s5    Movie        21     Robert Luketic
# 7         s8    Movie       187     Kevin Reynolds
# 10       s11    Movie      1922       Zak Hilditch
# 15       s16    Movie    Oct-01     Kunle Afolayan
# ...      ...      ...       ...                ...
# 7776   s7775    Movie    Zodiac      David Fincher
# 7778   s7777    Movie  Zokkomon   Satyajit Bhatkal
# 7782   s7781    Movie       Zoo       Shlok Sharma
# 7784   s7783    Movie      Zozo        Josef Fares
# 7785   s7784    Movie    Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 10    Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...
# 15    Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...
# ...

# %%
df[((df.Category=='Movie')&(df.Type.str.contains('Dramas',regex=True)))|((df.Category=='TV Show')&(df.Type.str.contains("Kids'",regex=True)))].Category.value_counts()
# Out:
# Movie      2038
# TV Show      13
# Name: Category, dtype: int64
