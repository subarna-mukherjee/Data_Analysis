# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('udemy_courses.csv',parse_dates=['published_timestamp'])

# %%
df
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
df.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
df.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %%
df.tail()
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %%
df.shape
#'number of rows ',df.shape[0]
#'number of cols ',df.shape[1]
# Out:
# (3678, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB

# %%
df.isnull().values.any()    #is there any null value?
# Out:
# False

# %%
sns.heatmap(df.isnull())    #checking for null values using heatmap
# Out:
# <AxesSubplot:>

# %%
df.duplicated().any()
# Out:
# True

# %%
df[df.duplicated()]
# Out:
#       course_id                                       course_title  \
# 787      837322  Essentials of money value: Get a financial Life !
# 788     1157298  Introduction to Forex Trading Business For Beg...
# 894     1035638                 Understanding Financial Statements
# 1100    1084454                  CFA Level 2- Quantitative Methods
# 1473     185526                             MicroStation - Células
# 2561      28295  Learn Web Designing & HTML5/CSS3 Essentials in...
#
#                                                     url  is_paid  price  \
# 787    https://www.udemy.com/essentials-of-money-value/     True     20
# 788   https://www.udemy.com/introduction-to-forex-tr...     True     20
# 894   https://www.udemy.com/understanding-financial-...     True     25
# 1100  https://www.udemy.com/cfa-level-2-quantitative...     True     40
# 1473        https://www.udemy.com/microstation-celulas/     True     20
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().any()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3672 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   int64
#  1   course_title         3672 non-null   object
#  2   url                  3672 non-null   object
#  3   is_paid              3672 non-null   bool
#  4   price                3672 non-null   int64
#  5   num_subscribers      3672 non-null   int64
#  6   num_reviews          3672 non-null   int64
#  7   num_lectures         3672 non-null   int64
#  8   level                3672 non-null   object
#  9   content_duration     3672 non-null   float64
#  10  published_timestamp  3672 non-null   datetime64[ns, UTC]
#  11  subject              3672 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 347.8+ KB

# %%
df.subject.value_counts()     #number of courses per subject
# Out:
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64

# %%
sns.countplot(x=df.subject)
plt.xlabel('Subjects')
plt.ylabel('Number of courses per subject')
#plt.figure(figsize=(15,15))
plt.xticks(rotation=65)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3672 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   int64
#  1   course_title         3672 non-null   object
#  2   url                  3672 non-null   object
#  3   is_paid              3672 non-null   bool
#  4   price                3672 non-null   int64
#  5   num_subscribers      3672 non-null   int64
#  6   num_reviews          3672 non-null   int64
#  7   num_lectures         3672 non-null   int64
#  8   level                3672 non-null   object
#  9   content_duration     3672 non-null   float64
#  10  published_timestamp  3672 non-null   datetime64[ns, UTC]
#  11  subject              3672 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 507.8+ KB

# %%
df.level.value_counts()
# the level for the courses(how many courses for each level)
# Out:
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
sns.countplot(x=df.level)
plt.xlabel('Level',fontsize=15)
plt.ylabel('Number of courses',fontsize=15)
#plt.xticks(rotation=35)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3672 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   int64
#  1   course_title         3672 non-null   object
#  2   url                  3672 non-null   object
#  3   is_paid              3672 non-null   bool
#  4   price                3672 non-null   int64
#  5   num_subscribers      3672 non-null   int64
#  6   num_reviews          3672 non-null   int64
#  7   num_lectures         3672 non-null   int64
#  8   level                3672 non-null   object
#  9   content_duration     3672 non-null   float64
#  10  published_timestamp  3672 non-null   datetime64[ns, UTC]
#  11  subject              3672 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 507.8+ KB

# %%
df.is_paid.value_counts()
#how many course are paid and  how many are free?
# Out:
# True     3362
# False     310
# Name: is_paid, dtype: int64

# %%
df.is_paid.replace({True:'Paid',False:'Free'},inplace=True)

# %%
sns.countplot(x=df.is_paid,hue=df.subject)
#plt.xlabel('')
plt.show()
#visualization of count of courses paid and free for each subject

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3672 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   int64
#  1   course_title         3672 non-null   object
#  2   url                  3672 non-null   object
#  3   is_paid              3672 non-null   object
#  4   price                3672 non-null   int64
#  5   num_subscribers      3672 non-null   int64
#  6   num_reviews          3672 non-null   int64
#  7   num_lectures         3672 non-null   int64
#  8   level                3672 non-null   object
#  9   content_duration     3672 non-null   float64
#  10  published_timestamp  3672 non-null   datetime64[ns, UTC]
#  11  subject              3672 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(5), object(5)
# memory usage: 532.9+ KB

# %%
df.groupby('is_paid').num_lectures.sum()
#which one free or paid has more lectures
# Out:
# is_paid
# Free      6639
# Paid    140756
# Name: num_lectures, dtype: int64

# %%
df.groupby('is_paid').corr()
# Out:
#                           course_id     price  num_subscribers  num_reviews  \
# is_paid
# Free    course_id          1.000000       NaN        -0.408402    -0.319547
#         price                   NaN       NaN              NaN          NaN
#         num_subscribers   -0.408402       NaN         1.000000     0.814563
#         num_reviews       -0.319547       NaN         0.814563     1.000000
#         num_lectures      -0.037221       NaN         0.172067     0.140318
#         content_duration  -0.096720       NaN         0.250321     0.233706
# Paid    course_id          1.000000  0.164744        -0.126491    -0.031600
#         price              0.164744  1.000000         0.229508     0.159097
#         num_subscribers   -0.126491  0.229508         1.000000     0.738684
#         num_reviews       -0.031600  0.159097         0.738684     1.000000
#         num_lectures      -0.023411  0.313864         0.278220     0.265314
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3672 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   int64
#  1   course_title         3672 non-null   object
#  2   url                  3672 non-null   object
#  3   is_paid              3672 non-null   object
#  4   price                3672 non-null   int64
#  5   num_subscribers      3672 non-null   int64
#  6   num_reviews          3672 non-null   int64
#  7   num_lectures         3672 non-null   int64
#  8   level                3672 non-null   object
#  9   content_duration     3672 non-null   float64
#  10  published_timestamp  3672 non-null   datetime64[ns, UTC]
#  11  subject              3672 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(5), object(5)
# memory usage: 532.9+ KB

# %%
df.groupby('is_paid').num_subscribers.mean()
# Out:
# is_paid
# Free    11533.951613
# Paid     2421.270077
# Name: num_subscribers, dtype: float64

# %%
sns.barplot(x=df.is_paid,y=df.num_subscribers)
plt.show()
#free courses has higher number of subscribers

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3672 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   int64
#  1   course_title         3672 non-null   object
#  2   url                  3672 non-null   object
#  3   is_paid              3672 non-null   object
#  4   price                3672 non-null   int64
#  5   num_subscribers      3672 non-null   int64
#  6   num_reviews          3672 non-null   int64
#  7   num_lectures         3672 non-null   int64
#  8   level                3672 non-null   object
#  9   content_duration     3672 non-null   float64
#  10  published_timestamp  3672 non-null   datetime64[ns, UTC]
#  11  subject              3672 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(5), object(5)
# memory usage: 532.9+ KB

# %%
df.num_subscribers.max()
# Out:
# 268923

# %%
df.groupby('level').num_subscribers.mean()
# Out:
# level
# All Levels            3569.761558
# Beginner Level        3195.459779
# Expert Level           865.448276
# Intermediate Level    1762.482185
# Name: num_subscribers, dtype: float64

# %%
sns.barplot(x=df.level,y=df.num_subscribers)
plt.xticks(rotation=90)
plt.show()
#visualizing the avg number of subscribers for various levels

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3672 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   int64
#  1   course_title         3672 non-null   object
#  2   url                  3672 non-null   object
#  3   is_paid              3672 non-null   object
#  4   price                3672 non-null   int64
#  5   num_subscribers      3672 non-null   int64
#  6   num_reviews          3672 non-null   int64
#  7   num_lectures         3672 non-null   int64
#  8   level                3672 non-null   object
#  9   content_duration     3672 non-null   float64
#  10  published_timestamp  3672 non-null   datetime64[ns, UTC]
#  11  subject              3672 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(5), object(5)
# memory usage: 532.9+ KB

# %%
df.num_subscribers.idxmax()
# Out:
# 2827

# %%
df.loc[2827,:].to_frame().T
#to find most popular course
# Out:
#      course_id                          course_title  \
# 2827     41295  Learn HTML5 Programming From Scratch
#
#                                                     url is_paid price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    Free     0
#
#      num_subscribers num_reviews num_lectures       level content_duration  \
# 2827          268923        8629           45  All Levels             10.5
#
#            published_timestamp          subject
# 2827 2013-02-14 07:03:41+00:00  Web Development

# %%
df[df.num_subscribers==df.num_subscribers.max()].course_title
#most popular course title
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %%
#5 most popular courses
df.num_subscribers.nlargest(n=5)
# Out:
# 2827    268923
# 3032    161029
# 3230    121584
# 2783    120291
# 3232    114512
# Name: num_subscribers, dtype: int64

# %%
top_5=df.loc[[2827,3032,3230,2783,3232],:]
top_5
#most popular courses
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
#
#                                                     url is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    Free      0
# 3032  https://www.udemy.com/coding-for-entrepreneurs...    Free      0
# 3230  https://www.udemy.com/the-web-developer-bootcamp/    Paid    200
# 2783  https://www.udemy.com/build-your-first-website...    Free      0
# 3232  https://www.udemy.com/the-complete-web-develop...    Paid    200
#
#       num_subscribers  num_reviews  num_lectures           level  \
# 2827           268923         8629            45      All Levels
# ...

# %%
sns.barplot(x='num_subscribers',y='course_title',data=top_5)
#sns.set(font_scale=2)
plt.figure(figsize=(15,8))
#plt.xticks(rotation=34)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3672 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   int64
#  1   course_title         3672 non-null   object
#  2   url                  3672 non-null   object
#  3   is_paid              3672 non-null   object
#  4   price                3672 non-null   int64
#  5   num_subscribers      3672 non-null   int64
#  6   num_reviews          3672 non-null   int64
#  7   num_lectures         3672 non-null   int64
#  8   level                3672 non-null   object
#  9   content_duration     3672 non-null   float64
#  10  published_timestamp  3672 non-null   datetime64[ns, UTC]
#  11  subject              3672 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(5), object(5)
# memory usage: 532.9+ KB

# %%
df.num_reviews.idxmax()
# Out:
# 3230

# %%
df.loc[df.num_reviews.idxmax,:].to_frame().T
#course with highest number of reviews
# Out:
#      course_id                course_title  \
# 3230    625204  The Web Developer Bootcamp
#
#                                                     url is_paid price  \
# 3230  https://www.udemy.com/the-web-developer-bootcamp/    Paid   200
#
#      num_subscribers num_reviews num_lectures       level content_duration  \
# 3230          121584       27445          342  All Levels               43
#
#            published_timestamp          subject
# 3230 2015-11-02 21:13:27+00:00  Web Development

# %%
df[df.num_reviews==df.num_reviews.max()]
# Out:
#       course_id                course_title  \
# 3230     625204  The Web Developer Bootcamp
#
#                                                     url is_paid  price  \
# 3230  https://www.udemy.com/the-web-developer-bootcamp/    Paid    200
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 3230           121584        27445           342  All Levels
#
#       content_duration       published_timestamp          subject
# 3230              43.0 2015-11-02 21:13:27+00:00  Web Development

# %%
#to visuallize which subject has highest number of reviews
plt.figure(figsize=(10,10))
sns.barplot(x='subject',y='num_reviews',data=df)

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3672 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   int64
#  1   course_title         3672 non-null   object
#  2   url                  3672 non-null   object
#  3   is_paid              3672 non-null   object
#  4   price                3672 non-null   int64
#  5   num_subscribers      3672 non-null   int64
#  6   num_reviews          3672 non-null   int64
#  7   num_lectures         3672 non-null   int64
#  8   level                3672 non-null   object
#  9   content_duration     3672 non-null   float64
#  10  published_timestamp  3672 non-null   datetime64[ns, UTC]
#  11  subject              3672 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(5), object(5)
# memory usage: 532.9+ KB

# %%
df.groupby('is_paid').num_reviews.mean()
# Out:
# is_paid
# Free    425.929032
# Paid    131.516359
# Name: num_reviews, dtype: float64

# %%
plt.figure(figsize=(10,10))
plt.xlabel('is_paid',fontsize=25)
plt.ylabel('number of reviews',fontsize=25)
sns.barplot(x='is_paid',y='num_reviews',data=df)
plt.show()
#this shows that the free courses fetch more reviews

# %%
slice=df.loc[:,['price','num_reviews']]

sns.scatterplot(data=slice,x='price',y='num_reviews')
plt.show()
#this shows that higher the price of course,higher the number of reviews)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3672 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   int64
#  1   course_title         3672 non-null   object
#  2   url                  3672 non-null   object
#  3   is_paid              3672 non-null   object
#  4   price                3672 non-null   int64
#  5   num_subscribers      3672 non-null   int64
#  6   num_reviews          3672 non-null   int64
#  7   num_lectures         3672 non-null   int64
#  8   level                3672 non-null   object
#  9   content_duration     3672 non-null   float64
#  10  published_timestamp  3672 non-null   datetime64[ns, UTC]
#  11  subject              3672 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(5), object(5)
# memory usage: 532.9+ KB

# %%
df[df.course_title.str.contains('python',case=False)]
#list of courses related to python
# Out:
#       course_id                                       course_title  \
# 14      1196544   Python Algo Trading: Sentiment Trading with News
# 30      1170894  Python Algo Stock Trading: Automate Your Trading!
# 41      1035472  Python for Finance: Investment Fundamentals & ...
# 147     1070886         Python Algo Trading: FX Trading with Oanda
# 334      815482               Stock Technical Analysis with Python
# 536      529828                     Python for Trading & Investing
# 762     1088656          Quantitative Trading Analysis with Python
# 863      902888          Investment Portfolio Analysis with Python
# 1682     546848  Learn to code in Python and learn Adobe Photos...
# 2497      16646                        Web Programming with Python
# 2528     391546        Learn Python and Django: Payment Processing
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# ...

# %%
print('Number of courses related to Python is: ',len(df[df.course_title.str.contains('python',case=False)]))
# Out:
# Number of courses related to Python is:  29

# %%
df_python=df[df.course_title.str.contains('python',case=False)]

# %%
python_top10=df_python.sort_values(by='num_subscribers',ascending=False).head(10)
python_top10
#top ten popular courses in python
# Out:
#       course_id                                       course_title  \
# 2497      16646                        Web Programming with Python
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# 2528     391546        Learn Python and Django: Payment Processing
# 3200     822444  Python and Django Full Stack Web Developer Boo...
# 3507     394832  Fun and creative web engineering with Python a...
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 3138     631128  Complete Python Web Course: Build 8 Python Web...
# 3197      76052  Try Django 1.9 | Build a Blog and Learn Python...
# 2681     477702  Python for Beginners: Python Programming Langu...
# 3203     970600                    REST APIs with Flask and Python
#
#                                                     url is_paid  price  \
# 2497  https://www.udemy.com/web-programming-with-pyt...    Paid     50
# 2570    https://www.udemy.com/coding-for-entrepreneurs/    Paid    195
# ...

# %%
sns.barplot(x='num_subscribers',y='course_title',data=python_top10)
plt.show()
#visualization for the top 10 courses for Python

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3672 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   int64
#  1   course_title         3672 non-null   object
#  2   url                  3672 non-null   object
#  3   is_paid              3672 non-null   object
#  4   price                3672 non-null   int64
#  5   num_subscribers      3672 non-null   int64
#  6   num_reviews          3672 non-null   int64
#  7   num_lectures         3672 non-null   int64
#  8   level                3672 non-null   object
#  9   content_duration     3672 non-null   float64
#  10  published_timestamp  3672 non-null   datetime64[ns, UTC]
#  11  subject              3672 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(5), object(5)
# memory usage: 532.9+ KB

# %%
# to find which year had max num of courses introduced
df['Year']=df.published_timestamp.dt.year

# %%
#to display how many  courses per subject,were introduced each year
df.groupby('Year').subject.value_counts()
# Out:
# Year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Graphic Design          10
#       Musical Instruments     10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         55
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          65
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       347
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Business Finance       223
#       Web Development        223
#       Graphic Design         155
#       Musical Instruments    112
# Name: subject, dtype: int64

# %%
df.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...    Paid    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#         published_timestamp           subject  Year
# 0 2017-01-18 20:58:58+00:00  Business Finance  2017

# %%
#find the year when maximum number of courses were introduced
total_course_year=df.groupby('Year').course_title.count().to_frame()
total_course_year.sort_values(by='course_title',ascending=False,inplace=True)
#In 2016,the maximum number of courses were launched

# %%
total_course_year.reset_index()
# Out:
#    Year  course_title
# 0  2016          1204
# 1  2015          1014
# 2  2017           713
# 3  2014           490
# 4  2013           201
# 5  2012            45
# 6  2011             5

# %%
#by visualizing, we also reach the same conclusion,thta in 2016, the max number of courses were launched
sns.countplot(data=df,x='Year')
plt.show()
